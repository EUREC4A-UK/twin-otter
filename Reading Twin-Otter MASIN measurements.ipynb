# %%
import xarray as xr

# %matplotlib inline

# %% [markdown]
# Example files downloaded from CEDA: http://data.ceda.ac.uk/badc/accacia/data/masin/

# %%
# !ls
# Out:
# bas-core_masin_20130322_r000_flight180_1hz.nc	Untitled.ipynb
# bas-core_masin_20130322_r000_flight180_50hz.nc

# %%
# because of how the flags are stored (units is '1b') decoding cf times fails
ds = xr.open_dataset('bas-core_masin_20130322_r000_flight180_1hz.nc', decode_times=False)

# plot as function of time
ds = ds.swap_dims(dict(data_point='Time'))

# %%
ds.TDEW_BUCK.plot()
